# %%
import pyttsx3
import datetime
import speech_recognition as sr
import wikipedia
import webbrowser

from AppOpener import open

engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
engine.setProperty('voices', voices[1].id)

def speak(audio):
    engine.say(audio)
    engine.runAndWait()

def wishMe():
    speak("Hello, my name is Jarvis, how may I help you?")

def takeCommand():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        r.pause_threshold = 1
        audio = r.listen(source)

    try:
        print("Recognizing...")
        query = r.recognize_google(audio, language='en-in')
        print(f"User said: {query}\n")
    except Exception as e:
        print("Say something valid")
        return "None"
    return query

if __name__ == "__main__":
    wishMe()
    if 1:
        query = takeCommand().lower()
        if 'wikipedia' in query:
            speak('Searching Wikipedia...')
            query = query.replace("wikipedia", "")
            results = wikipedia.summary(query, sentences=2)
            
            speak("According to Wikipedia")
            print(results)
            speak(results)

        elif 'open youtube' in query:
            webbrowser.open("https://www.youtube.com")
        elif 'open google' in query:
            webbrowser.open("https://www.google.com")
        elif 'open stackoverflow' in query:
            webbrowser.open("https://stackoverflow.com")
        elif 'time' in query:
            strTime = datetime.datetime.now().strftime("%H:%M:%S")
            print(strTime)
            speak(f"The time is {strTime}")
        elif 'weather' in query:
            webbrowser.open("https://www.accuweather.com")
        elif 'spotify' in query:
            open("Spotify")
        elif 'play music' in query:
            open("Spotify")
        elif 'calculator' in query:
            open("Calculator")
        elif 'camera' in query:
            open("Camera")
        elif 'take photo' in query:
            
            open("Camera")
            
            
        elif 'what all' in query:
            speak('I can tell you results from Wikipedia, open a few important apps and websites')
# Out:
# Listening...
# Recognizing...
# User said: open calculator
#
# OPENING CALCULATOR

# %%
import pyttsx3
import datetime
import speech_recognition as sr
import wikipedia
import webbrowser
import tkinter as tk
from AppOpener import open

engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
engine.setProperty('voices', voices[1].id)

root = tk.Tk()
root.title("alexa Voice Assistant")

def speak(audio):
    engine.say(audio)
    engine.runAndWait()

def wishMe():
    speak("Hello, my name is alexa, how may I help you?")

def takeCommand():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        r.pause_threshold = 1
        audio = r.listen(source)

    try:
        print("Recognizing...")
        query = r.recognize_google(audio, language='en-in')
        print(f"User said: {query}\n")
    except Exception as e:
        print("Say something valid")
        return "None"
    return query

def process_query():
    query = takeCommand().lower()
    if 'wikipedia' in query:
        speak('Searching Wikipedia...')
        query = query.replace("wikipedia", "")
        results = wikipedia.summary(query, sentences=2)
        speak("According to Wikipedia")
        print(results)
        speak(results)
    elif 'open youtube' in query:
        webbrowser.open("https://www.youtube.com")
    elif 'open google' in query:
        webbrowser.open("https://www.google.com")
    elif 'open stackoverflow' in query:
        webbrowser.open("https://stackoverflow.com")
    elif 'time' in query:
        strTime = datetime.datetime.now().strftime("%H:%M:%S")
        print(strTime)
        speak(f"The time is {strTime}")
    elif 'weather' in query:
        webbrowser.open("https://www.accuweather.com")
    elif 'spotify' in query:
        open("Spotify")
    elif 'play music' in query:
        open("Spotify")
    elif 'calculator' in query:
        open("Calculator")
    elif 'camera' in query:
        open("Camera")
    elif 'take photo' in query:
        open("Camera")
    elif 'what all' in query:
        speak('I can tell you results from Wikipedia, open a few important apps and websites')

# GUI elements
label = tk.Label(root, text="Press the button to start alexa")
label.pack()

button = tk.Button(root, text="Start alexa", command=process_query)
button.pack()

root.mainloop()

# %%
import sqlite3

# Define the path to your SQLite database file
db_path = r"C:\Users\hp\Desktop\memory.db"

# Establish a connection
conn = sqlite3.connect(db_path)

# Create a cursor
cursor = conn.cursor()

# Execute SQL queries
cursor.execute('SELECT * FROM questionsAndAnswers')
data = cursor.fetchall()

# Close cursor and connection
cursor.close()
conn.close()

# %%
import pyttsx3
import datetime
import speech_recognition as sr
import wikipedia
import webbrowser
import os
import sqlite3

from AppOpener import open

engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
engine.setProperty('voices', voices[1].id)

def speak(audio):
    engine.say(audio)
    engine.runAndWait()

def wishMe():
    speak("Hello, my name is Jarvis, how may I help you?")

conn = None
cursor = None
def initialize_database():
    global conn, cursor
    conn = sqlite3.connect("C:\\Users\\hp\\command_log.db")
    cursor = conn.cursor()
    cursor.execute('''CREATE TABLE IF NOT EXISTS command_log (
                    id INTEGER PRIMARY KEY,
                    timestamp DATETIME,
                    user_command TEXT,
                    jarvis_response TEXT
                )''')
    conn.commit()

def log_command(query, response):
    current_time = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    cursor.execute('INSERT INTO command_log (timestamp, user_command, jarvis_response) VALUES (?, ?, ?)',
                   (current_time, query, response))
    conn.commit()
    

def takeCommand():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        r.pause_threshold = 1
        audio = r.listen(source)

    try:
        print("Recognizing...")
        query = r.recognize_google(audio, language='en-in')
        print(f"User said: {query}\n")
    except Exception as e:
        print("Say something valid")
        return "None"
    return query

if __name__ == "__main__":
    initialize_database()
    wishMe()
    if 1:
        query = takeCommand().lower()
        if 'wikipedia' in query:
            speak('Searching Wikipedia...')
            query = query.replace("wikipedia", "")
            results = wikipedia.summary(query, sentences=2)
            
            speak("According to Wikipedia")
            print(results)
            speak(results)

            log_command(query, results)

        elif 'open youtube' in query:
            webbrowser.open("https://www.youtube.com")
        elif 'open google' in query:
            webbrowser.open("https://www.google.com")
        elif 'open stackoverflow' in query:
            webbrowser.open("https://stackoverflow.com")
        elif 'time' in query:
            strTime = datetime.datetime.now().strftime("%H:%M:%S")
            print(strTime)
            speak(f"The time is {strTime}")

            log_command(query, f"The time is {strTime}")

        elif 'weather' in query:
            webbrowser.open("https://www.accuweather.com")
        elif 'spotify' in query:
            open("Spotify")

            log_command(query, "Opening Spotify")

        elif 'play music' in query:
            open("Spotify")

            log_command(query, "Playing music on Spotify")

        elif 'calculator' in query:
            open("Calculator")

            log_command(query, "Opening Calculator")

        elif 'camera' in query:
            open("Camera")

            log_command(query, "Opening Camera")

        elif 'take photo' in query:
            open("Camera")

            log_command(query, "Opening Camera to take a photo")

        elif 'what all' in query:
            speak('I can tell you results from Wikipedia, open a few important apps and websites')

# %%
import sqlite3

# Connect to the SQLite database
conn = sqlite3.connect("C:\\Users\\hp\\command_log.db")
cursor = conn.cursor()

# Execute a SELECT query to retrieve data from the command_log table
cursor.execute("SELECT * FROM command_log")

# Fetch and print all rows from the table
rows = cursor.fetchall()
for row in rows:
    print(row)

# Close the database connection
conn.close()

# %%
import sqlite3

# Define the database file path
db_file_path = "C:\\Users\\hp\\command_log.db"  # Modify this to your desired path

# Connect to the SQLite database
conn = sqlite3.connect(db_file_path)
cursor = conn.cursor()

# Create a table if it doesn't exist
cursor.execute('''
    CREATE TABLE IF NOT EXISTS command_log (
        id INTEGER PRIMARY KEY,
        timestamp DATETIME,
        user_command TEXT,
        jarvis_response TEXT
    )
''')
conn.commit()

# Function to log a command and response
def log_command(query, response):
    current_time = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")
    cursor.execute('INSERT INTO command_log (timestamp, user_command, jarvis_response) VALUES (?, ?, ?)',
                   (current_time, query, response))
    conn.commit()

# Usage example: log a command and response
log_command("User's command", "Jarvis's response")

# Close the database connection
conn.close()

# %%
import pyttsx3
import datetime
import speech_recognition as sr
import wikipedia
import webbrowser
import tkinter as tk
import os

engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
engine.setProperty('voices', voices[1].id)

def speak(audio):
    engine.say(audio)
    engine.runAndWait()

def wishMe():
    speak("Hello, my name is Jarvis, how may I help you?")

def takeCommand():
    r = sr.Recognizer()
    with sr.Microphone() as source:
        print("Listening...")
        r.pause_threshold = 1
        audio = r.listen(source)

    try:
        print("Recognizing...")
        query = r.recognize_google(audio, language='en-in')
        print(f"User said: {query}\n")
    except Exception as e:
        print("Say something valid")
        return "None"
    return query

def process_query():
    query = takeCommand().lower()
    if 'wikipedia' in query:
        speak('Searching Wikipedia...')
        query = query.replace("wikipedia", "")
        results = wikipedia.summary(query, sentences=2)
        speak("According to Wikipedia")
        print(results)
        speak(results)
    elif 'open youtube' in query:
        webbrowser.open("https://www.youtube.com")
    elif 'open google' in query:
        webbrowser.open("https://www.google.com")
    elif 'open stackoverflow' in query:
        webbrowser.open("https://stackoverflow.com")
    elif 'time' in query:
        strTime = datetime.datetime.now().strftime("%H:%M:%S")
        print(strTime)
        speak(f"The time is {strTime}")
    elif 'open calculator' in query:
        os.system('calc')
    elif 'open camera' in query:
        os.system('start microsoft.windows.camera:')
    # Add more conditions here for other actions

if __name__ == "__main__":
    window = tk.Tk()
    window.title("Jarvis - Your Virtual Assistant")

    wishMe()

    query_button = tk.Button(window, text="Recognize and Respond", command=process_query)
    query_button.pack()

    window.mainloop()
